# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "the quick brown fox jumps over the lazy dog",
    "never jump over the lazy dog quickly",
    "bright foxes leap over lazy dogs in the night"
]

# %%
vectorizer=TfidfVectorizer()
X=vectorizer.fit_transform(corpus)

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['bright' 'brown' 'dog' 'dogs' 'fox' 'foxes' 'in' 'jump' 'jumps' 'lazy'
#  'leap' 'never' 'night' 'over' 'quick' 'quickly' 'the']

# %%
print(X.toarray())
# Out:
# [[0.         0.38716197 0.29444666 0.         0.38716197 0.
#   0.         0.         0.38716197 0.22866409 0.         0.
#   0.         0.22866409 0.38716197 0.         0.45732819]
#  [0.         0.         0.35364183 0.         0.         0.
#   0.         0.46499651 0.         0.27463443 0.         0.46499651
#   0.         0.27463443 0.         0.46499651 0.27463443]
#  [0.37671579 0.         0.         0.37671579 0.         0.37671579
#   0.37671579 0.         0.         0.22249441 0.37671579 0.
#   0.37671579 0.22249441 0.         0.         0.22249441]]
